# %%
from gluoncv import utils, data, model_zoo
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-7d3b5e1e6056> in <module>
# ----> 1 from gluoncv import utils, data, model_zoo
#       2 from matplotlib import pyplot as plt
#       3
#
# d:\software_setup\python37\lib\site-packages\gluoncv\__init__.py in <module>
#       7 mx_version = '1.3.0'
#       8 try:
# ----> 9     import mxnet as mx
#      10     from distutils.version import LooseVersion
#      11     if LooseVersion(mx.__version__) < LooseVersion(mx_version):
#
# d:\software_setup\python37\lib\site-packages\mxnet\__init__.py in <module>
#      22 from __future__ import absolute_import
#      23
# ---> 24 from .context import Context, current_context, cpu, gpu, cpu_pinned
#      25 from . import engine
#      26 from .base import MXNetError
#
# d:\software_setup\python37\lib\site-packages\mxnet\context.py in <module>
#      22 import warnings
#      23 import ctypes
# ---> 24 from .base import classproperty, with_metaclass, _MXClassPropertyMetaClass
#      25 from .base import _LIB
#      26 from .base import check_call
#
# d:\software_setup\python37\lib\site-packages\mxnet\base.py in <module>
#     211 __version__ = libinfo.__version__
#     212 # library instance of mxnet
# --> 213 _LIB = _load_lib()
#     214
#     215 # type definitions
#
# d:\software_setup\python37\lib\site-packages\mxnet\base.py in _load_lib()
#     202     """Load library by searching possible path."""
#     203     lib_path = libinfo.find_lib_path()
# --> 204     lib = ctypes.CDLL(lib_path[0], ctypes.RTLD_LOCAL)
#     205     # DMatrix functions
#     206     lib.MXGetLastError.restype = ctypes.c_char_p
#
# d:\software_setup\python37\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     362
#     363         if handle is None:
# --> 364             self._handle = _dlopen(self._name, mode)
#     365         else:
#     366             self._handle = handle
#
# OSError: [WinError 1455] 页面文件太小，无法完成操作。

# %%
net = model_zoo.yolo3_darknet53_voc(pretrained=True)
im_fname = utils.download('https://raw.githubusercontent.com/zhreshold/' +
                          'mxnet-ssd/master/data/demo/dog.jpg',
                          path='dog.jpg')
x, img = data.transforms.presets.yolo.load_test(im_fname, short=512)
# Out:
# Model file is not found. Downloading.
# Downloading C:\Users\LXL\.mxnet\models\yolo3_darknet53_voc-f5ece5ce.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/yolo3_darknet53_voc-f5ece5ce.zip...
# Downloading dog.jpg from https://raw.githubusercontent.com/zhreshold/mxnet-ssd/master/data/demo/dog.jpg...
# 223070KB [02:24, 1540.85KB/s]
# 100%|██████████| 160/160 [00:00<00:00, 201.39KB/s]

# %%
class_IDs, scores, bounding_boxes = net(x)
axe = utils.viz.plot_bbox(img, bounding_boxes[0], scores[0], class_IDs[0], thresh=0.9, class_names=net.classes)
plt.show()
